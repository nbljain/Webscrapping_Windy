# %%
#yhat pan error aalay...ekda bagh
#he code correct run jahaala paije naa...yhachavar loop wala code based aahe
from selenium import webdriver

from selenium.webdriver.common.keys import Keys

from selenium.webdriver.common.by import By

import time

import pandas as pd

from bs4 import BeautifulSoup

from selenium.webdriver.chrome.service import Service

from webdriver_manager.chrome import ChromeDriverManager

from random import randrange

s=Service(ChromeDriverManager().install())

driver = webdriver.Chrome(service=s)

driver.maximize_window()

###########################################

random_num = randrange(15,25)

driver.get('https://www.windy.com/28.040/78.790/wind?27.506,78.788,8,m:erTaimu')

click = driver.find_element(By.XPATH,'//*[@id="login"]').click()

time.sleep(random_num)

login = driver.find_element(By.XPATH,'//*[@id="email"]')

login.send_keys('ashish.redfx')

password = driver.find_element(By.XPATH,'//*[@id="password"]')

password.send_keys('Red@123$')

password.send_keys(Keys.ENTER)

location = driver.find_element(By.XPATH,'//*[@id="q"]')

location.send_keys('23.81039,75.06278')

i = 1
while i<15:
    
    location.send_keys(Keys.ENTER)
    i = i+1
time.sleep(random_num)

#location.send_keys(Keys.ENTER)
driver.find_element(By.XPATH,'/html/body/div[4]/div[1]/div[5]/div[1]').click()

page_source = driver.page_source

soup = BeautifulSoup(page_source,'lxml')

### DATA EXTRACTION FROM ECW
time.sleep(random_num)

p = driver.find_element(By.XPATH,'//*[@id="detail-data-table"]/tbody/tr[3]')

f = [int(i) for i in p.text.split() if i.isdigit()]
min_ECW = []

max_ECW = []

for i in range(0,len(f)):
    if i%2:
        max_ECW.append(f[i])
    else:
        min_ECW.append(f[i])
min_ECW,max_ECW

f3 = pd.DataFrame(list(zip(min_ECW,max_ECW)),columns = ['Min Speed(m/s)_ECW','Max Speed(m/s)_ECW'])

### DATA EXTRACTION FROM GFS

s = driver.find_element(By.XPATH,'//*[@id="detail-data-table"]/tbody/tr[4]')

e = [int(i) for i in s.text.split() if i.isdigit()]

min_GFS = []

max_GFS = []

for i in range(0,len(e)):
    if i%2:
        max_GFS.append(e[i])
    else:
        min_GFS.append(e[i])
        
min_GFS,max_GFS

f2 = pd.DataFrame(list(zip(min_GFS,max_GFS)),columns = ['Min Speed(m/s)_GFS','Max Speed(m/s)_GFS'])

### EXTRACTING DATA FROM ICON

time.sleep(random_num)

a = driver.find_element(By.XPATH,'//*[@id="detail-data-table"]/tbody/tr[5]')

b= [int(i) for i in a.text.split() if i.isdigit()]

min_ICON = []

max_ICON = []

for i in range(0,len(b)):
    if i%2:
        max_GFS.append(b[i])
    else:
        min_GFS.append(b[i])
        
min_ICON,max_ICON

f4 = pd.DataFrame(list(zip(min_ICON,max_ICON)),columns = ['Min Speed(m/s)_ICON','Max Speed(m/s)_ICON'])

### EXTRACTING DATA FROM METEOBLUE

c = driver.find_element(By.XPATH,'//*[@id="detail-data-table"]/tbody/tr[6]')

d= [int(i) for i in c.text.split() if i.isdigit()]

min_MB = []

max_MB = []

for i in range(0,len(d)):
    if i%2:
        max_MB.append(d[i])
    else:
        min_MB.append(d[i])
        
min_MB,max_MB

f5 = pd.DataFrame(list(zip(min_MB,max_MB)),columns = ['Min Speed(m/s)_MB','Max Speed(m/s)_MB'])

time.sleep(random_num)

### EXTRACTING TIME DATA

time = driver.find_element(By.XPATH,'//*[@id="detail-data-table"]/tbody/tr[2]')

time_split= time.text.split()

t = pd.DataFrame(time_split)

## COMBINING THE FINAL DATAFRAME

new= []
for i in range(1,78):
    titles = driver.find_element(By.XPATH,'//*[@id="detail-data-table"]/tbody/tr[2]/td['+str(i)+']').get_attribute("data-ts")
    new.append(titles)
data = pd.DataFrame(new)

datatime= pd.to_datetime(data.iloc[:,0],unit = 'ms')

td = pd.DataFrame(datatime)

df_FINAL = pd.concat([td,f3,f2,f4,f5],axis = 1)

pd.set_option('display.max_rows' ,78)

df_FINAL.columns = ['DATATIME','UGRD100M','VGRD100M','T2M','DIR_HI','CLDCVR', 'SURF_PRESSURE', 'WIND_DIR_100M','WIND_SPEED_100M']

#df_1 = pd.DataFrame(columns=['CLDCVR', 'SURF_PRESSURE', 'WIND_DIR_100M','WIND_SPEED_100M'])

#df = pd.concat([df_FINAL,df_1])
df_FINAL
# Out:
# [WDM] - ====== WebDriver manager ======
# [WDM] - Current google-chrome version is 102.0.5005
# [WDM] - Get LATEST chromedriver version for 102.0.5005 google-chrome
# [WDM] - Driver [/home/nitin/.wdm/drivers/chromedriver/linux64/102.0.5005.61/chromedriver] found in cache
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [10], in <cell line: 80>()
#      77         min_ECW.append(f[i])
#      78 min_ECW,max_ECW
# ---> 80 f3 = pd.DataFrame(list(zip(min_ECW,max_ECW)),columns = ['Min Speed(m/s)_ECW','Max Speed(m/s)_ECW'])
#      82 ### DATA EXTRACTION FROM GFS
#      84 s = driver.find_element(By.XPATH,'//*[@id="detail-data-table"]/tbody/tr[4]')
#
# TypeError: 'list' object is not callable

# %%
#### LOOPING...he error kadhi yet ani kadhi naahi.....tu jevayla ja nantar bghu aaj nhi tr udya..jevha tu free asel
## ok....khali lheeelelea code i am sure correct aahe...parat karto...

# %%
from selenium import webdriver

from selenium.webdriver.common.keys import Keys

from selenium.webdriver.common.by import By

import time

import pandas as pd

from bs4 import BeautifulSoup

from selenium.webdriver.chrome.service import Service

from webdriver_manager.chrome import ChromeDriverManager

from random import randrange

list = ['23.81039,75.06278','23.92733,71.20236','22.27069,69.54383']

###########################################


for i in list:
    s=Service(ChromeDriverManager().install())

    driver = webdriver.Chrome(service=s)

    driver.maximize_window()

    random_num = randrange(15,25)
    
    driver.get('https://www.windy.com/28.040/78.790/wind?27.506,78.788,8,m:erTaimu')

    click = driver.find_element(By.XPATH,'//*[@id="login"]').click()

    time.sleep(random_num)

    login = driver.find_element(By.XPATH,'//*[@id="email"]')

    login.send_keys('ashish.redfx')

    password = driver.find_element(By.XPATH,'//*[@id="password"]')

    password.send_keys('Red@123$')

    password.send_keys(Keys.ENTER)

    location = driver.find_element(By.XPATH,'//*[@id="q"]')


    location.send_keys(i)
    
    print(i)

    j = 1
    while j<15:
    
        location.send_keys(Keys.ENTER)
        j = j+1
        time.sleep(random_num)

#location.send_keys(Keys.ENTER)
    driver.find_element(By.XPATH,'/html/body/div[4]/div[1]/div[5]/div[1]').click()

    page_source = driver.page_source

    soup = BeautifulSoup(page_source,'lxml')

### DATA EXTRACTION FROM ECW
    time.sleep(random_num)

    p = driver.find_element(By.XPATH,'//*[@id="detail-data-table"]/tbody/tr[3]')

    f = [int(i) for i in p.text.split() if i.isdigit()]
    min_ECW = []

    max_ECW = []

    for i in range(0,len(f)):
        if i%2:
            max_ECW.append(f[i])
        else:
            min_ECW.append(f[i])
    min_ECW,max_ECW
    
    try:
        f3 = pd.DataFrame(list(zip(min_ECW,max_ECW)),columns = ['Min Speed(m/s)_ECW','Max Speed(m/s)_ECW'])
    except :
        pass
### DATA EXTRACTION FROM GFS

    s = driver.find_element(By.XPATH,'//*[@id="detail-data-table"]/tbody/tr[4]')

    e = [int(i) for i in s.text.split() if i.isdigit()]

    min_GFS = []

    max_GFS = []

    for i in range(0,len(e)):
        if i%2:
            max_GFS.append(e[i])
        else:
            min_GFS.append(e[i])
        
    min_GFS,max_GFS

    f2 = pd.DataFrame(list(zip(min_GFS,max_GFS)),columns = ['Min Speed(m/s)_GFS','Max Speed(m/s)_GFS'])

### EXTRACTING TIME DATA

    time = driver.find_element(By.XPATH,'//*[@id="detail-data-table"]/tbody/tr[2]')

    time_split= time.text.split()

    t = pd.DataFrame(time_split)

## COMBINING THE FINAL DATAFRAME

    new= []
    for i in range(1,78):
        titles = driver.find_element(By.XPATH,'//*[@id="detail-data-table"]/tbody/tr[2]/td['+str(i)+']').get_attribute("data-ts")
        new.append(titles)
    data = pd.DataFrame(new)

    datatime= pd.to_datetime(data.iloc[:,0],unit = 'ms')

    td = pd.DataFrame(datatime)

    df_FINAL = pd.concat([td,f3,f2],axis = 1)

    pd.set_option('display.max_rows' ,78)

    df_FINAL.columns = ['DATATIME','UGRD100M','VGRD100M','T2M','DIR_HI']

    df_1 = pd.DataFrame(columns=['CLDCVR', 'SURF_PRESSURE', 'WIND_DIR_100M','WIND_SPEED_100M'])

    df = pd.concat([df_FINAL,df_1])

    df

# %%
# prateek : I am quite sure the code in this cell is correct...
from selenium import webdriver

from selenium.webdriver.common.keys import Keys

from selenium.webdriver.common.by import By

import time

import pandas as pd

from bs4 import BeautifulSoup

from selenium.webdriver.chrome.service import Service

from webdriver_manager.chrome import ChromeDriverManager

from random import randrange

def data_extraction (loc):
    from selenium import webdriver

    from selenium.webdriver.common.keys import Keys

    from selenium.webdriver.common.by import By

    import time

    import pandas as pd

    from bs4 import BeautifulSoup

    from selenium.webdriver.chrome.service import Service

    from webdriver_manager.chrome import ChromeDriverManager

    from random import randrange

    s=Service(ChromeDriverManager().install())

    driver = webdriver.Chrome(service=s)

    driver.maximize_window()

    ###########################################

    random_num = randrange(15,25)

    driver.get('https://www.windy.com/28.040/78.790/wind?27.506,78.788,8,m:erTaimu')

    click = driver.find_element(By.XPATH,'//*[@id="login"]').click()

    time.sleep(randrange(15,25))

    login = driver.find_element(By.XPATH,'//*[@id="email"]')

    login.send_keys('ashish.redfx')

    password = driver.find_element(By.XPATH,'//*[@id="password"]')

    password.send_keys('Red@123$')

    password.send_keys(Keys.ENTER)

    location = driver.find_element(By.XPATH,'//*[@id="q"]')

    location.send_keys(loc)

    i = 1
    while i<15:

        location.send_keys(Keys.ENTER)
        i = i+1
    time.sleep(randrange(15,25))

    #location.send_keys(Keys.ENTER)
    driver.find_element(By.XPATH,'/html/body/div[4]/div[1]/div[5]/div[1]').click()

    page_source = driver.page_source

    soup = BeautifulSoup(page_source,'lxml')

    ### DATA EXTRACTION FROM ECW
    time.sleep(random_num)

    p = driver.find_element(By.XPATH,'//*[@id="detail-data-table"]/tbody/tr[3]')

    f = [int(i) for i in p.text.split() if i.isdigit()]
    min_ECW = []

    max_ECW = []

    for i in range(0,len(f)):
        if i%2:
            max_ECW.append(f[i])
        else:
            min_ECW.append(f[i])
    min_ECW,max_ECW

    try :
        f3 = pd.DataFrame(list(zip(min_ECW,max_ECW)),columns = ['Min Speed(m/s)_ECW','Max Speed(m/s)_ECW'])
    except :
        f3= pd.DataFrame()
    ### DATA EXTRACTION FROM GFS

    s = driver.find_element(By.XPATH,'//*[@id="detail-data-table"]/tbody/tr[4]')

    e = [int(i) for i in s.text.split() if i.isdigit()]

    min_GFS = []

    max_GFS = []

    for i in range(0,len(e)):
        if i%2:
            max_GFS.append(e[i])
        else:
            min_GFS.append(e[i])

    min_GFS,max_GFS
    
    try :

        f2 = pd.DataFrame(list(zip(min_GFS,max_GFS)),columns = ['Min Speed(m/s)_GFS','Max Speed(m/s)_GFS'])
    except :
        f2  = pd.DataFrame()
    ### EXTRACTING DATA FROM ICON

    time.sleep(randrange(15,25))

    a = driver.find_element(By.XPATH,'//*[@id="detail-data-table"]/tbody/tr[5]')

    b= [int(i) for i in a.text.split() if i.isdigit()]

    min_ICON = []

    max_ICON = []

    for i in range(0,len(b)):
        if i%2:
            max_GFS.append(b[i])
        else:
            min_GFS.append(b[i])

    min_ICON,max_ICON
    try:

        f4 = pd.DataFrame(list(zip(min_ICON,max_ICON)),columns = ['Min Speed(m/s)_ICON','Max Speed(m/s)_ICON'])
    except :
        f4= pd.DataFrame()
    ### EXTRACTING DATA FROM METEOBLUE

    c = driver.find_element(By.XPATH,'//*[@id="detail-data-table"]/tbody/tr[6]')

    d= [int(i) for i in c.text.split() if i.isdigit()]

    min_MB = []

    max_MB = []

    for i in range(0,len(d)):
        if i%2:
            max_MB.append(d[i])
        else:
            min_MB.append(d[i])

    min_MB,max_MB
    
    try :

        f5 = pd.DataFrame(list(zip(min_MB,max_MB)),columns = ['Min Speed(m/s)_MB','Max Speed(m/s)_MB'])
    except :
        f5= pd.DataFrame()
    time.sleep(random_num)

    ### EXTRACTING TIME DATA

    time = driver.find_element(By.XPATH,'//*[@id="detail-data-table"]/tbody/tr[2]')

    time_split= time.text.split()

    t = pd.DataFrame(time_split)

    ## COMBINING THE FINAL DATAFRAME

    new= []
    for i in range(1,78):
        titles = driver.find_element(By.XPATH,'//*[@id="detail-data-table"]/tbody/tr[2]/td['+str(i)+']').get_attribute("data-ts")
        new.append(titles)
    data = pd.DataFrame(new)

    datatime= pd.to_datetime(data.iloc[:,0],unit = 'ms')

    td = pd.DataFrame(datatime)
    

    df_FINAL = pd.concat([td,f3,f2,f4,f5],axis = 1)

    pd.set_option('display.max_rows' ,78)
    try :
        

        df_FINAL.columns = ['DATATIME','UGRD100M','VGRD100M','T2M','DIR_HI','CLDCVR', 'SURF_PRESSURE', 'WIND_DIR_100M','WIND_SPEED_100M']

    except:
        return pd.DataFrame()
    #df_1 = pd.DataFrame(columns=['CLDCVR', 'SURF_PRESSURE', 'WIND_DIR_100M','WIND_SPEED_100M'])

    #df = pd.concat([df_FINAL,df_1])
    
    return df_FINAL

list = ['23.81039,75.06278','23.92733,71.20236']
dataframes=[]
for location in list:
    print(location)
    time.sleep(randrange(15,25))
    dataframe = data_extraction(location)
    dataframes.append(dataframe)
# Out:
# 23.81039,75.06278
# [WDM] - ====== WebDriver manager ======
# [WDM] - Current google-chrome version is 102.0.5005
# [WDM] - Get LATEST chromedriver version for 102.0.5005 google-chrome
# [WDM] - Driver [/home/nitin/.wdm/drivers/chromedriver/linux64/102.0.5005.61/chromedriver] found in cache
# 23.92733,71.20236
# [WDM] - ====== WebDriver manager ======
# [WDM] - Current google-chrome version is 102.0.5005
# [WDM] - Get LATEST chromedriver version for 102.0.5005 google-chrome
# [WDM] - Driver [/home/nitin/.wdm/drivers/chromedriver/linux64/102.0.5005.61/chromedriver] found in cache

# %%
#why we are not getting data?
# Let the code run fully...spotted a mistake...wait......okay # corrected the mistake...location function madhe pass hot nhavta...amhi jevayla challot...ratri room la gelya var karto...dokadukhi tu kaahi karat naahis kaam mhanti aahe
#then it must show NaN
len(dataframes)
dataframes[1]
#dataframes
#u there?
# Out:
# Empty DataFrame
# Columns: []
# Index: []
